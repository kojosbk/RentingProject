# %% [markdown]
# # Rent in Ghana

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Data Cleaning (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
# ## Project Objectives
#
# * Clean the dataset to the point where it can be used effectively for model design

# %% [markdown]
# ## Definition of Data Features
#
#
#
# 1. Title
# 2. Location
# 3. Price

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section we would import, and briefly discuss, the libraries that will be used throughout our analysis and modelling. |
#
# ---

# %% [markdown]
# ### Import the packages that are neccessary to carry out the stated objectives of the project

# %%
# Libraries for data loading, data manipulation and data visulisation
import numpy as np # for linear algebra
import pandas as pd # Data processing, CSV file importation

# Libraries for data preparation and model building

#Machine learning performance libraries
from sklearn.metrics import mean_squared_error
from sklearn import *
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold




#other packages
from datetime import datetime
import re
import handcalcs.render

#Visualization Packages
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# Set option to display all columns
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section we load the data from the `df` file into a DataFrame. |
#
# ---

# %% [markdown]
# To begin loading our data, we need to make sure that the raw data and the notebook file are both in the same folder on our local machine. Both the train and test data sets will be loaded into our notebook using the code below. If the files aren't in the same folder, we'll have to point to the directory where the file is stored on our machine or on the cloud. It is a good practice to call up the loaded data once it has been loaded to ensure that the data has loaded correctly.

# %%
# load the train data
df= pd.read_csv('20augrentghana.csv')
dfr= pd.read_csv('List of all state_s in Ghana with Latitude and Longitude.csv')
dfs= pd.read_csv('List of all suburb_s in Ghana with Latitude and Longitude.csv')
 
df.head()
# Out:
#                                                                                    Title  \
# 0                                    \n        3bdrm Apartment in Spintex for Rent\n
# 1  \n        Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent\n
# 2                 \n        2bdrm Apartment in West Trassaco, Adjiriganor for Rent\n
# 3                    \n        3bdrm Duplex in Spintex, Tema Metropolitan for Rent\n
# 4       \n        Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan\n
#
#                         Price  \
# 0   \n        GH₵ 3,500\n
# 1  \n        GH₵ 32,000\n
# 2   \n        GH₵ 3,500\n
# 3   \n        GH₵ 6,400\n
# 4     \n        GH₵ 800\n
#
#                                                                                                                                                    Description  \
# 0  \n                            Semi furnished 3 bedrooms apartment,\n2 washrooms,\n2 spacious balconies,\nDinning area,\nFitted...\n
# 1                                               \n                            4 bedroom townhouse + going for ; \nLocated Cantonment\n
# 2     \n                            Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom\n
# 3  \n                            Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...\n
# 4                      \n                            Separate meter, Available water .Space for car pack, big dinning hall and pouch\n
#
#                                                    Location
# 0            \n            Greater Accra, Spintex\n
# 1        \n            Greater Accra, Cantonments\n
# 2        \n            Greater Accra, Adjiriganor\n
# 3  \n            Greater Accra, Tema Metropolitan\n
# 4      \n            Ashanti, Kumasi Metropolitan\n

# %%
dfr
# Out:
#                  Regions  Latitude_Regions  Longitude_Regions
# 0           ahafo region          6.916885          -2.535097
# 1         ashanti region          6.800332          -1.518814
# 2       bono east region          7.803524          -1.087649
# 3            bono region          7.676179          -2.473540
# 4         central region          5.724415          -1.376175
# 5         eastern region          6.446877          -0.377096
# 6   greater accra region          5.810153           0.099524
# 7      north east region         10.395977          -0.541079
# 8        northern region          9.660000          -0.394380
# 9             oti region          7.863387           0.318598
# 10       savannah region          9.140065          -1.711123
# 11     upper west region         10.366953          -2.092143
# 12          volta region          6.534862           0.455605
# 13  western north region          6.227937          -2.823489
# 14        western region          5.426124          -2.128657

# %%
dfs.head()
# Out:
#              Suburb Latitude_Suburb  Longitude_Suburb
# 0         abawdikro     7.609215999         -1.960575
# 1             abeka     5.599984099         -0.241833
# 2         abelenkpe     5.608003599         -0.217334
# 3  ablekuma newtown     5.637302199         -0.313772
# 4            aboabo     6.701056199         -1.596086

# %% [markdown]
# ### Dataset summary
# It is important to identify the columns that have null entries as null values can affect the performance of our model. The "isnull" function shows the number of null values that are contained in each column of the dataset. This data set is relatively clean
# Pandas dataframe.info() function is used to get a concise summary of the dataframe

# %%
def Summary(df):
    i = df.info()
    print ("NUL Values")
    n = df.isna().sum()
    return i,n

# %%
Summary(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        940 non-null    object
#  1   Price        940 non-null    object
#  2   Description  940 non-null    object
#  3   Location     940 non-null    object
# dtypes: object(4)
# memory usage: 29.5+ KB
# NUL Values
# (None,
#  Title          0
#  Price          0
#  Description    0
#  Location       0
#  dtype: int64)

# %% [markdown]
# ### Check the "Shape" of the data-sets
# The data has been split into two sets, as evidenced by the form of both datasets. Seventy-five percent of the data is designated as train data, whereas twenty-five percent is designated as test data. The shape also reveals that the training data set includes 49 columns, whereas the test data set only has 48. The column that our model is supposed to predict is the one that is absent from the test set. We may find that specific object by looking for the entity (Column) that is missing from the test data set. That column can be identified as the load shortfall 3hr column after looking at both datasets.

# %%
df.shape
# Out:
# (940, 4)

# %% [markdown]
# <a id="three"></a>
# ## 3. Data Cleaning (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# | ⚡ Description: Data Cleaning ⚡ |
# | :--------------------------- |
# | In this section, we are required to perform an in-depth analysis of all the variables in the DataFrame. |

# %%
#Extracting the price collumn from the title
df['Price'] = df['Price'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
df.tail()
# Out:
#                                                                                   Title  \
# 935                   \n        5bdrm Duplex in Living Large, East Legon for Rent\n
# 936          \n        Furnished 3bdrm Apartment in Tamale Airport Road. For Rent\n
# 937    \n        Furnished 1bdrm Apartment in East Legon, American House for Rent\n
# 938  \n        1bdrm Apartment in Divine Mercy Agency, Awutu Senya East Municipal\n
# 939                        \n        2bdrm Apartment in Tamale, Shishegu for Rent\n
#
#      Price  \
# 935   9000
# 936   3000
# 937   7480
# 938    400
# 939    700
#
#                                                                                                                                                             Description  \
# 935     \n                            Executive 5 bedroom newly built house with a boy’s quarters for rent at west trasacco very nice also...\n
# 936                                         \n                            V.I.P furnished apartment house for rent on the Tamale airport road\n
# 937       \n                            This beautiful chamber and hall Apartment is going for 3months or 1year advance it,s so affordable...\n
# 938  \n                            Chamber and hall self contained.\nLocated at Choice weija\ngoing for 400gh accept 1year rent.\nWall and...\n
# 939               \n                            2 bedroom apartment self compound,comes with p.o.p,nice kitchen, washroom, water flows always\n
#
#                                                                Location
# 935                   \n            Greater Accra, East Legon\n
# 936           \n            Northern Region, Tamale Municipal\n
# 937                   \n            Greater Accra, East Legon\n
# 938  \n            Central Region, Awutu Senya East Municipal\n
# 939           \n            Northern Region, Tamale Municipal\n

# %%
#removing "\n" from the title
df = df.replace(r'\n',' ', regex=True) 
df.head()
# Out:
#                                                                                  Title  \
# 0                                             3bdrm Apartment in Spintex for Rent
# 1           Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                          2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                             3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
#
#    Price  \
# 0   3500
# 1  32000
# 2   3500
# 3   6400
# 4    800
#
#                                                                                                                                                  Description  \
# 0                                   Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                             4 bedroom townhouse + going for ;  Located Cantonment
# 2                                  Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                               Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                   Separate meter, Available water .Space for car pack, big dinning hall and pouch
#
#                                                  Location
# 0                         Greater Accra, Spintex
# 1                     Greater Accra, Cantonments
# 2                     Greater Accra, Adjiriganor
# 3               Greater Accra, Tema Metropolitan
# 4                   Ashanti, Kumasi Metropolitan

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section we would be: cleaning the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %% [markdown]
# ### 4.1 The Importance of Feature Engineering in data science?
# In Data Science, the quality of data input into a model determines the model's performance. Data preprocessing and data handling are commonly used to improve data quality. Let's say we develop a model without engineering the data and attain a 40 percent accuracy. The model's performance can be improved by up to 70% or more by doing feature engineering on the same data before feeding it to the model.
#
# Simply, by using Feature Engineering we improve can the performance of the model greatly. As we saw in the previous section (EDA), we highlighted some columns to be dropped as well as columns with categorical values.
#
# We will now do the following:

# %%
#extracting 
df['Rooms'] = df['Title'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
# #convert the Romss colum to string
df['Rooms'] = df['Rooms'].astype(str)
# extracting the first number
df['Rooms'] = df['Rooms'].str.extract('(\d{,1})')
df["Rooms"] = pd.to_numeric(df["Rooms"])
# df.loc[df['Rooms'] > 10]

# %%
Summary(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        940 non-null    object
#  1   Price        940 non-null    int32
#  2   Description  940 non-null    object
#  3   Location     940 non-null    object
#  4   Rooms        936 non-null    float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 33.2+ KB
# NUL Values
# (None,
#  Title          0
#  Price          0
#  Description    0
#  Location       0
#  Rooms          4
#  dtype: int64)

# %%
df.head(290)
# Out:
#                                                                                    Title  \
# 0                                               3bdrm Apartment in Spintex for Rent
# 1             Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                            2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                               3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                  Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
# ..                                                                                   ...
# 285                                              5bdrm House in East Legon for Rent
# 286                       Furnished 3bdrm Apartment in Airport Residential for Rent
# 287                                     2bdrm Apartment in Íke, East Legon for Rent
# 288                      3bdrm Apartment in Kings Properties, Old Ashomang for Rent
# 289                                     2bdrm Apartment in Abokobi Council for Rent
#
#      Price  \
# 0     3500
# 1    32000
# 2     3500
# 3     6400
# 4      800
# ..     ...
# 285  15600
# 286  36000
# 287   1700
# 288   2700
# 289   1500
#
#                                                                                                                                                        Description  \
# 0                                         Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                                   4 bedroom townhouse + going for ;  Located Cantonment
# 2                                        Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                                     Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                         Separate meter, Available water .Space for car pack, big dinning hall and pouch
# ..                                                                                                                                                             ...
# 285                                      5-bedroom house with 1bq to-let at East Legon not far from Emanuel eye clinic asking price is...
# 286                                  3 BEDROOM APARTMENT LETTING IN WEST AIRPORT RESIDENTIAL AREA, ACCRA.  $4500 Living in the highest...
# 287                                                     2 BEDROOMS 2 WASHROOMS 1700 Newly Built Agbogba 3 tenants to be on the compounded
# 288                                Three bedroom self compound,gated community at old ashongman ghc 2,700 a month for one year.contact...
# 289                               Two bedroom apartment for rent at Abokobi council... 24/7water flow and gated and walled as well has...
#
#                                                           Location  Rooms
# 0                                  Greater Accra, Spintex             3.0
# 1                              Greater Accra, Cantonments             4.0
# 2                              Greater Accra, Adjiriganor             2.0
# 3                        Greater Accra, Tema Metropolitan             3.0
# 4                            Ashanti, Kumasi Metropolitan             2.0
# ..                                                             ...    ...
# 285                             Greater Accra, East Legon             5.0
# 286               Greater Accra, Airport Residential Area             3.0
# 287                             Greater Accra, East Legon             2.0
# 288                           Greater Accra, Old Ashomang             3.0
# 289                                Greater Accra, Abokobi             2.0
#
# [290 rows x 5 columns]

# %%
#identify the empty columns
df[df['Rooms'].isna()]
# Out:
#                                                                       Title  \
# 38                            An Executive Four Bedroom House for Rent
# 293                             Mini Flat in Adenta Municipal for Rent
# 478           Executive Newly Built House For Rent At East Legon Hills
# 499                  Very Big Store at Fuel Station for Rent in Tamale
#
#      Price  \
# 38   11480
# 293   1000
# 478   2500
# 499    700
#
#                                                                                                                                                        Description  \
# 38                                  4-bedrooms house plus boys quarter with fully loaded kitchen, fitted air conditioners in all rooms...
# 293                               1Bedroom flat, huge hall, huge bedroom, visitors washroom, AC available,separate meter, neat kitchen...
# 478                               *executive newly  built 3 bedroom house for rent at east legon hills   *price:ghc 2,500   **spacious...
# 499                                                                                              Fuel station super market/store for rent
#
#                                                     Location  Rooms
# 38                Greater Accra, Accra Metropolitan             NaN
# 293                           Greater Accra, Adenta             NaN
# 478                       Greater Accra, East Legon             NaN
# 499               Northern Region, Tamale Municipal             NaN

# %%
df['Rooms'] = df['Rooms'].fillna(pd.to_numeric(df['Description'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)))

# %%
df.head(500)
# Out:
#                                                                                    Title  \
# 0                                               3bdrm Apartment in Spintex for Rent
# 1             Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                            2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                               3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                  Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
# ..                                                                                   ...
# 495                       1bdrm Apartment in Mic Properties, Ashaley Botwe for Rent
# 496               1bdrm Apartment in Divine Mercy Agency, Awutu Senya West for Rent
# 497                                4bdrm House in Living Large, East Legon for Rent
# 498                                                3bdrm Apartment in Dome for Rent
# 499                               Very Big Store at Fuel Station for Rent in Tamale
#
#      Price  \
# 0     3500
# 1    32000
# 2     3500
# 3     6400
# 4      800
# ..     ...
# 495    800
# 496    300
# 497   8500
# 498   1500
# 499    700
#
#                                                                                                                                                      Description  \
# 0                                       Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                                 4 bedroom townhouse + going for ;  Located Cantonment
# 2                                      Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                                   Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                       Separate meter, Available water .Space for car pack, big dinning hall and pouch
# ..                                                                                                                                                           ...
# 495                                                                                        Chamber and hall s/c for rent @ Ashley Botwe
# 496                                      Chamber and hall self contained  Located at Lamptey area kasoa going for 300gh accept 1year...
# 497                               4 BEDROOM LUXURIOUS HOUSE FOR RENT East legon Ajiriganor  4 bedrooms is available for tent at East...
# 498                                     Executive standard ultramodern newly built three bedrooms apartment located in a nice serene...
# 499                                                                                            Fuel station super market/store for rent
#
#                                                     Location  Rooms
# 0                            Greater Accra, Spintex             3.0
# 1                        Greater Accra, Cantonments             4.0
# 2                        Greater Accra, Adjiriganor             2.0
# 3                  Greater Accra, Tema Metropolitan             3.0
# 4                      Ashanti, Kumasi Metropolitan             2.0
# ..                                                       ...    ...
# 495                    Greater Accra, Ashaley Botwe             1.0
# 496                Central Region, Awutu Senya West             1.0
# 497                       Greater Accra, East Legon             4.0
# 498                             Greater Accra, Dome             3.0
# 499               Northern Region, Tamale Municipal             NaN
#
# [500 rows x 5 columns]

# %%
# droping empty rows in price
df = df.drop(labels=499, axis=0)

# %%
#checking if nan values have been filled
df.head(500)
# Out:
#                                                                                    Title  \
# 0                                               3bdrm Apartment in Spintex for Rent
# 1             Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                            2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                               3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                  Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
# ..                                                                                   ...
# 495                       1bdrm Apartment in Mic Properties, Ashaley Botwe for Rent
# 496               1bdrm Apartment in Divine Mercy Agency, Awutu Senya West for Rent
# 497                                4bdrm House in Living Large, East Legon for Rent
# 498                                                3bdrm Apartment in Dome for Rent
# 500              Furnished 5bdrm Townhouse/Terrace in Eastlegon, Accra Metropolitan
#
#      Price  \
# 0     3500
# 1    32000
# 2     3500
# 3     6400
# 4      800
# ..     ...
# 495    800
# 496    300
# 497   8500
# 498   1500
# 500  22400
#
#                                                                                                                                                      Description  \
# 0                                       Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                                 4 bedroom townhouse + going for ;  Located Cantonment
# 2                                      Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                                   Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                       Separate meter, Available water .Space for car pack, big dinning hall and pouch
# ..                                                                                                                                                           ...
# 495                                                                                        Chamber and hall s/c for rent @ Ashley Botwe
# 496                                      Chamber and hall self contained  Located at Lamptey area kasoa going for 300gh accept 1year...
# 497                               4 BEDROOM LUXURIOUS HOUSE FOR RENT East legon Ajiriganor  4 bedrooms is available for tent at East...
# 498                                     Executive standard ultramodern newly built three bedrooms apartment located in a nice serene...
# 500                                    FOR RENT: Newly Built 5 Bedroom Town House for rent #Location Eastlegon  Price-$3,500 for all...
#
#                                                     Location  Rooms
# 0                            Greater Accra, Spintex             3.0
# 1                        Greater Accra, Cantonments             4.0
# 2                        Greater Accra, Adjiriganor             2.0
# 3                  Greater Accra, Tema Metropolitan             3.0
# 4                      Ashanti, Kumasi Metropolitan             2.0
# ..                                                       ...    ...
# 495                    Greater Accra, Ashaley Botwe             1.0
# 496                Central Region, Awutu Senya West             1.0
# 497                       Greater Accra, East Legon             4.0
# 498                             Greater Accra, Dome             3.0
# 500               Greater Accra, Accra Metropolitan             5.0
#
# [500 rows x 5 columns]

# %%
#from line 603 we see some values in the rooms column have 2 figures
Summary(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 939 entries, 0 to 939
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        939 non-null    object
#  1   Price        939 non-null    int32
#  2   Description  939 non-null    object
#  3   Location     939 non-null    object
#  4   Rooms        939 non-null    float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 40.3+ KB
# NUL Values
# (None,
#  Title          0
#  Price          0
#  Description    0
#  Location       0
#  Rooms          0
#  dtype: int64)

# %%
df.loc[df['Rooms'] >= 9]
# Out:
#                                                                                 Title  \
# 478                     Executive Newly Built House For Rent At East Legon Hills
# 531           EXECUTIVE 9 BEDROOMS FOR RENTALS AT EAST LEGON A&C MALL FOR 4000 $
#
#      Price  \
# 478   2500
# 531  20000
#
#                                                                                                                                                        Description  \
# 478                               *executive newly  built 3 bedroom house for rent at east legon hills   *price:ghc 2,500   **spacious...
# 531                                        EXECUTIVE 9 BEDROOMS   AND A GARDEN #Location: EAST LEGON-A&C MALL # RESIDENTIAL AND OFFICE...
#
#                                               Location    Rooms
# 478                 Greater Accra, East Legon           32500.0
# 531               Greater Accra, Agbogbloshie               9.0

# %%
#extracting the first 2 element of the column
df['Rooms'] = df.Rooms.astype(str).str[:1]

# %%
# extracting the numbers to get rid of the comma
df['Rooms'] = df['Rooms'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
#checking if line 603 is fixed
df.head(604)
# Out:
#                                                                                    Title  \
# 0                                               3bdrm Apartment in Spintex for Rent
# 1             Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                            2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                               3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                  Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
# ..                                                                                   ...
# 600                      2bdrm Apartment in the Dorns Properties, New Town for Rent
# 601                                          3bdrm Apartment in East Legon for Rent
# 602                            2bdrm Apartment in Living Large, East Legon for Rent
# 603                                          2bdrm Apartment in East Legon for Rent
# 604                                Furnished 2bdrm Apartment in East Legon for Rent
#
#      Price  \
# 0     3500
# 1    32000
# 2     3500
# 3     6400
# 4      800
# ..     ...
# 600   1300
# 601   2800
# 602   3500
# 603   2000
# 604   8000
#
#                                                                                                                                                      Description  \
# 0                                       Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                                 4 bedroom townhouse + going for ;  Located Cantonment
# 2                                      Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                                   Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                       Separate meter, Available water .Space for car pack, big dinning hall and pouch
# ..                                                                                                                                                           ...
# 600                                Executive newly built 2 bedroom apartment for rent @ teshie bush road, separate light meter,water...
# 601                                 2 bedroom  American House - East Legon. ...  1 year Accepted. 2 years Accepted... etc ...  Newly...
# 602                                       Executive 2 bedroom apartment house to let at west trasacco not far from the main trasacco...
# 603                               Newly built 2 bedrooms, spacious, glazed, p.o.p, water and electricity available, balcony, kitchen...
# 604                                                                Executive fully-furnished 2bedroom at East legon ability is for rent
#
#                                                    Location  Rooms
# 0                           Greater Accra, Spintex               3
# 1                       Greater Accra, Cantonments               4
# 2                       Greater Accra, Adjiriganor               2
# 3                 Greater Accra, Tema Metropolitan               3
# 4                     Ashanti, Kumasi Metropolitan               2
# ..                                                      ...    ...
# 600                          Greater Accra, Teshie               2
# 601                      Greater Accra, East Legon               3
# 602                      Greater Accra, East Legon               2
# 603                      Greater Accra, East Legon               2
# 604                      Greater Accra, East Legon               2
#
# [604 rows x 5 columns]

# %%
Summary(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 939 entries, 0 to 939
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        939 non-null    object
#  1   Price        939 non-null    int32
#  2   Description  939 non-null    object
#  3   Location     939 non-null    object
#  4   Rooms        939 non-null    int32
# dtypes: int32(2), object(3)
# memory usage: 36.7+ KB
# NUL Values
# (None,
#  Title          0
#  Price          0
#  Description    0
#  Location       0
#  Rooms          0
#  dtype: int64)

# %%
df.head()
# Out:
#                                                                                  Title  \
# 0                                             3bdrm Apartment in Spintex for Rent
# 1           Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                          2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                             3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
#
#    Price  \
# 0   3500
# 1  32000
# 2   3500
# 3   6400
# 4    800
#
#                                                                                                                                                  Description  \
# 0                                   Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                             4 bedroom townhouse + going for ;  Located Cantonment
# 2                                  Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                               Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                   Separate meter, Available water .Space for car pack, big dinning hall and pouch
#
#                                                  Location  Rooms
# 0                         Greater Accra, Spintex               3
# 1                     Greater Accra, Cantonments               4
# 2                     Greater Accra, Adjiriganor               2
# 3               Greater Accra, Tema Metropolitan               3
# 4                   Ashanti, Kumasi Metropolitan               2

# %%
df["Location"] = df["Location"].str.strip() #striping the Location collum
df["Location"] = df["Location"].str.lower() #converting to lowercase
df['Regions'] = df['Location'].str.split(',').str[0] #extracting similar Regions
df['Suburb'] = df['Location'].str.split(',').str[1] #extracting similar Subrb
df['Suburb'] = df['Suburb'].str.strip()
df
sorted(df["Location"].unique())
df.head()
# Out:
#                                                                                  Title  \
# 0                                             3bdrm Apartment in Spintex for Rent
# 1           Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                          2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                             3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
#
#    Price  \
# 0   3500
# 1  32000
# 2   3500
# 3   6400
# 4    800
#
#                                                                                                                                                  Description  \
# 0                                   Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                             4 bedroom townhouse + going for ;  Located Cantonment
# 2                                  Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                               Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                   Separate meter, Available water .Space for car pack, big dinning hall and pouch
#
#                            Location  Rooms        Regions               Suburb
# 0            greater accra, spintex      3  greater accra              spintex
# 1        greater accra, cantonments      4  greater accra          cantonments
# 2        greater accra, adjiriganor      2  greater accra          adjiriganor
# 3  greater accra, tema metropolitan      3  greater accra    tema metropolitan
# 4      ashanti, kumasi metropolitan      2        ashanti  kumasi metropolitan

# %%
sorted(df["Regions"].unique())
# Out:
# ['ashanti',
#  'brong ahafo',
#  'central region',
#  'eastern region',
#  'greater accra',
#  'northern region',
#  'volta region',
#  'western region']

# %%
df['Regions'] = df['Regions'].str.replace(' region', '')
df['Regions'] = df['Regions'].str.replace('brong ', '')

# %%
sorted(df["Regions"].unique())
# Out:
# ['ahafo',
#  'ashanti',
#  'central',
#  'eastern',
#  'greater accra',
#  'northern',
#  'volta',
#  'western']

# %%
df['Regions'] =df['Regions'].astype(str)+' region'

# %%
sorted(df["Regions"].unique())
# Out:
# ['ahafo region',
#  'ashanti region',
#  'central region',
#  'eastern region',
#  'greater accra region',
#  'northern region',
#  'volta region',
#  'western region']

# %%
new_df = pd.merge(df, dfr,  how='left', on=["Regions"])

# %%
new_df
# Out:
#                                                                                    Title  \
# 0                                               3bdrm Apartment in Spintex for Rent
# 1             Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                            2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                               3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                  Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
# ..                                                                                   ...
# 934                               5bdrm Duplex in Living Large, East Legon for Rent
# 935                      Furnished 3bdrm Apartment in Tamale Airport Road. For Rent
# 936                Furnished 1bdrm Apartment in East Legon, American House for Rent
# 937              1bdrm Apartment in Divine Mercy Agency, Awutu Senya East Municipal
# 938                                    2bdrm Apartment in Tamale, Shishegu for Rent
#
#      Price  \
# 0     3500
# 1    32000
# 2     3500
# 3     6400
# 4      800
# ..     ...
# 934   9000
# 935   3000
# 936   7480
# 937    400
# 938    700
#
#                                                                                                                                                        Description  \
# 0                                         Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                                   4 bedroom townhouse + going for ;  Located Cantonment
# 2                                        Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                                     Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                         Separate meter, Available water .Space for car pack, big dinning hall and pouch
# ..                                                                                                                                                             ...
# 934                               Executive 5 bedroom newly built house with a boy’s quarters for rent at west trasacco very nice also...
# 935                                                                   V.I.P furnished apartment house for rent on the Tamale airport road
# 936                                 This beautiful chamber and hall Apartment is going for 3months or 1year advance it,s so affordable...
# 937                               Chamber and hall self contained. Located at Choice weija going for 400gh accept 1year rent. Wall and...
# 938                                         2 bedroom apartment self compound,comes with p.o.p,nice kitchen, washroom, water flows always
#
#                                        Location  Rooms               Regions  \
# 0                        greater accra, spintex      3  greater accra region
# 1                    greater accra, cantonments      4  greater accra region
# 2                    greater accra, adjiriganor      2  greater accra region
# 3              greater accra, tema metropolitan      3  greater accra region
# 4                  ashanti, kumasi metropolitan      2        ashanti region
# ..                                          ...    ...                   ...
# 934                   greater accra, east legon      5  greater accra region
# 935           northern region, tamale municipal      3       northern region
# 936                   greater accra, east legon      1  greater accra region
# 937  central region, awutu senya east municipal      1        central region
# 938           northern region, tamale municipal      2       northern region
#
#                          Suburb  Latitude_Regions  Longitude_Regions
# 0                       spintex          5.810153           0.099524
# 1                   cantonments          5.810153           0.099524
# 2                   adjiriganor          5.810153           0.099524
# 3             tema metropolitan          5.810153           0.099524
# 4           kumasi metropolitan          6.800332          -1.518814
# ..                          ...               ...                ...
# 934                  east legon          5.810153           0.099524
# 935            tamale municipal          9.660000          -0.394380
# 936                  east legon          5.810153           0.099524
# 937  awutu senya east municipal          5.724415          -1.376175
# 938            tamale municipal          9.660000          -0.394380
#
# [939 rows x 9 columns]

# %%
new_df1 = pd.merge(new_df, dfs,  how='left', on=["Suburb"])

# %%
new_df1.head()
# Out:
#                                                                                  Title  \
# 0                                             3bdrm Apartment in Spintex for Rent
# 1           Furnished 4bdrm Townhouse/Terrace in Cantonment, Cantonments for Rent
# 2                          2bdrm Apartment in West Trassaco, Adjiriganor for Rent
# 3                             3bdrm Duplex in Spintex, Tema Metropolitan for Rent
# 4                Furnished 2bdrm House in Glory Vel Junction, Kumasi Metropolitan
#
#    Price  \
# 0   3500
# 1  32000
# 2   3500
# 3   6400
# 4    800
#
#                                                                                                                                                  Description  \
# 0                                   Semi furnished 3 bedrooms apartment, 2 washrooms, 2 spacious balconies, Dinning area, Fitted...
# 1                                                                             4 bedroom townhouse + going for ;  Located Cantonment
# 2                                  Newly built 2bedroom apartment in west trassaco for rent at a price of 3500 cedis ... 3 washroom
# 3                               Nice 3 Bedroom Duplex For Rent in a serene area at Spintex. It comes with all rooms ensuite with...
# 4                                                   Separate meter, Available water .Space for car pack, big dinning hall and pouch
#
#                            Location  Rooms               Regions  \
# 0            greater accra, spintex      3  greater accra region
# 1        greater accra, cantonments      4  greater accra region
# 2        greater accra, adjiriganor      2  greater accra region
# 3  greater accra, tema metropolitan      3  greater accra region
# 4      ashanti, kumasi metropolitan      2        ashanti region
#
#                 Suburb  Latitude_Regions  Longitude_Regions Latitude_Suburb  \
# 0              spintex          5.810153           0.099524     5.628826499
# 1          cantonments          5.810153           0.099524     5.584156299
# 2          adjiriganor          5.810153           0.099524           5.651
# 3    tema metropolitan          5.810153           0.099524          5.6477
# 4  kumasi metropolitan          6.800332          -1.518814         6.68848
#
#    Longitude_Suburb
# 0         -0.090199
# 1         -0.169249
# 2         -0.135400
# 3         -0.001500
# 4         -1.624430

# %%
Summary(new_df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 939 entries, 0 to 938
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        939 non-null    object
#  1   Price        939 non-null    int32
#  2   Description  939 non-null    object
#  3   Location     939 non-null    object
#  4   Rooms        939 non-null    int32
#  5   Regions      939 non-null    object
#  6   Suburb       939 non-null    object
#  7   Latitude     939 non-null    object
#  8   Longitude    939 non-null    float64
# dtypes: float64(1), int32(2), object(6)
# memory usage: 66.0+ KB
# NUL Values
# (None,
#  Title          0
#  Price          0
#  Description    0
#  Location       0
#  Rooms          0
#  Regions        0
#  Suburb         0
#  Latitude       0
#  Longitude      0
#  dtype: int64)

# %%
#identify the empty columns
samp = new_df1[new_df1['Latitude'].isna()]

# %%
sorted(samp["Suburb"].unique())
# Out:
# ['ablekuma',
#  'accra metropolitan',
#  'achimota',
#  'adenta',
#  'adjiriganor',
#  'agbogba',
#  'agbogbloshie',
#  'akuapim south',
#  'ashaiman municipal',
#  'ashomang estate',
#  'awutu senya east municipal',
#  'awutu senya west',
#  'dodowa',
#  'dworwulu',
#  'ga east municipal',
#  'ga south municipal',
#  'ga west municipal',
#  'gomoa east',
#  'haatso',
#  'ho municipal',
#  'kasoa',
#  'kumasi metropolitan',
#  'kwashieman',
#  'madina',
#  'new-juaben municipal',
#  'north legon',
#  'old ashomang',
#  'oyarifa',
#  'oyibi',
#  'ridge',
#  'shama ahanta east metropolitan',
#  'south la',
#  'south shiashie',
#  'sowutwuom',
#  'sunyani municipal',
#  'taifa-burkina',
#  'takoradi',
#  'tamale municipal',
#  'tantra hills',
#  'tarkwa nsuaem',
#  'tema metropolitan',
#  'teshie',
#  'weija',
#  'west legon']

# %%
sorted(dfs["Suburb"].unique())
# Out:
# ['abawdikro',
#  'abeka',
#  'abelenkpe',
#  'ablekuma newtown',
#  'aboabo',
#  'abofu',
#  'abokobi',
#  'abossey okai',
#  'abouabo',
#  'abrepo',
#  'abusuakruwa',
#  'accra new town',
#  'adentan',
#  'adisadel',
#  'adjiringanor',
#  'adoato',
#  'adum',
#  'adum-line',
#  'adumanu',
#  'afful nkwanta',
#  'agdegya',
#  'agric',
#  'ahodwo',
#  'airport residential area',
#  'akutubo',
#  'akwatia-line',
#  'akweteyman',
#  'alabar',
#  'alaji',
#  'alajo',
#  'alogboshie',
#  'amakom',
#  'amasaman',
#  'amedenuta',
#  'amoabisi',
#  'ampabame',
#  'anfoeta zongo',
#  'anomangye',
#  'antem',
#  'anwomaso',
#  'aprade',
#  'aputuogya',
#  'area 2',
#  'area 4',
#  'asafo',
#  'asawase',
#  'aseebu',
#  'asem',
#  'ashaley botwe',
#  'ashongman',
#  'ashtown',
#  'asikafoamantem',
#  'asokore mampong',
#  'asokwa',
#  'asongen',
#  'asufufu',
#  'asuogya',
#  'asylum down',
#  'atafoa',
#  'atonkwa, elmina',
#  'atorkukope',
#  'atta mills',
#  'avakome',
#  'avoeme',
#  'awoshie',
#  'awudome estates',
#  'ayeduase',
#  'ayi mensah',
#  'ayigbe town',
#  'ayigya',
#  'baakoniaba',
#  'bantama',
#  'banvum',
#  'bari',
#  'bawa villa',
#  'begyeahaso',
#  'benkute',
#  'beo',
#  'berlin top',
#  'bethlehem',
#  'blockso',
#  'boadi',
#  'bobkrom',
#  'bofre ase',
#  'bohyen',
#  'bomso',
#  'brahabebome',
#  'breman',
#  'breman north',
#  'bukere',
#  'bukom',
#  'bulpiela',
#  'buokrom',
#  'buokrom estate',
#  'burma camp',
#  'cantonments',
#  'changi',
#  'chapel hill',
#  'choggu',
#  'chorkor',
#  'christian village',
#  'community 1',
#  'community 10',
#  'community 11',
#  'community 12',
#  'community 17',
#  'community 18',
#  'community 2',
#  'community 22',
#  'community 25',
#  'community 3',
#  'community 4',
#  'community 5',
#  'community 6',
#  'community 7',
#  'community 8',
#  'community 9',
#  'cuba',
#  'dabokpaa',
#  'daboren',
#  'dagbandabo fong',
#  'dansoman',
#  'danyame',
#  'daporetindongo',
#  'darkuman',
#  'dechem',
#  'deduako',
#  'dichemso',
#  'dixcove hill',
#  'dome',
#  'dotoba zongo',
#  'dulugu',
#  'duuli',
#  'dzorwulu',
#  'east airport',
#  'east legon',
#  'east legon hills',
#  'ecomog',
#  'effiduase',
#  'esreso',
#  'fante new town',
#  'feyiasi',
#  'fiapre anhwere',
#  'first ridge',
#  'fou',
#  'freetown',
#  'galiliea',
#  'gbanbaya',
#  'george baryeh',
#  'gmc',
#  'government hill',
#  'greda estate',
#  'green hill',
#  'green view',
#  'gumani',
#  'hausa zong',
#  'hedzranawo',
#  'iture',
#  'jakarayili town',
#  'james town',
#  'kaase',
#  'kabore',
#  'kakasunaka no.1',
#  'kakpagayili',
#  'kakraba down',
#  'kalpohin',
#  'kalpohin estates',
#  'kambali',
#  'kanda estates',
#  'kaneshie',
#  'kantia',
#  'kantunso',
#  'kasalgo',
#  'katanga',
#  'kenyasi no.1',
#  'kenyasi no.2',
#  'kisseman',
#  'kokoado',
#  'kokoase',
#  'kokompe',
#  'konta',
#  'korle gonno',
#  'korlebu',
#  'kotei',
#  'kotobabi',
#  'kpaguri',
#  'kpedze lowcost',
#  'krapa',
#  'krofuom',
#  'kronum',
#  'kropo',
#  'kukuo town',
#  'kumbosku',
#  'kunbiasi',
#  'kunkoa',
#  'kwabenya',
#  'kwadaso',
#  'kwadaso estate',
#  'kwansakrom',
#  'kwasi bukro',
#  'kyanshiogo',
#  'labone',
#  'lamashegu',
#  'lantemame',
#  'lapaz',
#  'lartebiokorshie',
#  'little legon',
#  'low cost',
#  'low cost estate',
#  'lowcost',
#  'maamobi',
#  'mallam',
#  'mallam borla',
#  'mamprobi',
#  'mangu',
#  'masalatsi',
#  'mataheko',
#  'mbrom',
#  'mccarthy hill',
#  'mendskrom',
#  'ministries',
#  'mohiyarinh',
#  'morta',
#  'moshie zongo',
#  'mozukrom',
#  'mpatasie',
#  'mpoase',
#  'nakaba',
#  'nalong fong',
#  'namolgo',
#  'nanakrom',
#  'nasalat',
#  'new abelekuma',
#  'new achimota',
#  'new denkyira',
#  'new gbawe',
#  'new legon',
#  'new russia',
#  'new takoradi',
#  'new town',
#  'new weija',
#  'newtown',
#  'ngleshie amanfro',
#  'nhyiaeso',
#  'nii boi town',
#  'nima',
#  'nkroma nkwanta',
#  'nkwabeng',
#  'nkwaeso',
#  'north dzorwolu',
#  'north industrial area',
#  'north kaneshie',
#  'north ridge',
#  'north suntreso',
#  'ntoaso',
#  'nyamekye',
#  'nyaniba estates',
#  'nyanshegu',
#  'nyohini',
#  'nyorkoko',
#  'obenyade',
#  'odorkor',
#  'odumase',
#  'oduom',
#  'ofankor',
#  'official town',
#  'oforikrom',
#  'ohwim',
#  'ola',
#  'old fadama',
#  'old town',
#  'opetekwe',
#  'osu',
#  'otojor',
#  'paring',
#  'parkoso',
#  'patasi',
#  'pedu',
#  'pepre point',
#  'plotso',
#  'pobiman',
#  'pokuase',
#  'quarters',
#  'race course',
#  'regimanuel gray estate',
#  'ringway estates',
#  'roman hill',
#  'roman ridge',
#  'russia',
#  'sakasaka',
#  'saki',
#  'sakote',
#  'sakumono west cong. territory',
#  'salamba',
#  'sambo',
#  'santasi',
#  'santoe',
#  'sarpeiman',
#  'sawaba',
#  'sawaliga',
#  'sebrepor',
#  'senase',
#  'sherigu',
#  'sheshagu',
#  'shikakope',
#  'sigameri',
#  'sofoline',
#  'sokabissi',
#  'soli korpe',
#  'south industrial area',
#  'south la estates',
#  'south odorkor estates',
#  'south suntreso',
#  'sowutuom',
#  'spintex',
#  'ssnit flats',
#  'suame',
#  'susanso',
#  'tabora',
#  'tafo',
#  'takofiano',
#  'tanokrom',
#  'tanoso',
#  'tarkwa zongo',
#  'tarkwa-maakro',
#  'tengzug',
#  'tesano',
#  'teshie nungua estates',
#  'the point',
#  'tindongo',
#  'tindonmolgo',
#  'tishigu town',
#  'trasacco valley',
#  'tua',
#  'tulaku',
#  'ussher town',
#  'valco estades',
#  'viepe',
#  'vitin',
#  'vitin estate',
#  'warizehi',
#  'watchman',
#  'west ridge',
#  'westland',
#  'windy ridge',
#  'yarigabisi',
#  'yepala',
#  'yepasi',
#  'yikene',
#  'zanlerigo',
#  'zarre',
#  'zongo',
#  'zonno',
#  'zonno zoore',
#  'zujung']
